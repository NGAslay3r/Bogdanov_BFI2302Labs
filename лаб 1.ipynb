# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БФИ2302 Богданов Иван Дмитриевич

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time
def generate_matrix(rows, cols, min_val, max_val):
    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)    
    return matrix

my_matrix = generate_matrix(3, 3, 0, 100)
print(my_matrix)
# Out:
# [[92, 36, 97], [87, 57, 14], [40, 39, 27]]

# %%
import random
user_m = int(input("m = "))
user_n = int(input("n = "))
user_min_limit = int(input())
user_max_limit = int(input())

matrix = []
for i in range(user_m):
    row = [random.randint(user_min_limit, user_max_limit) for _ in range(user_n)]
    matrix.append(row)

print("Матрица:")
for row in matrix:
    print(row)
# Out:
# Матрица:
# [2, 35, 45]
# [72, 81, 82]
# [83, 3, 13]
# [85, 19, 47]
# [65, 22, 47]

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
# Сортировка выбором.
import copy
import random
import time

start_time = time.time()

def generate_matrix(rows, cols, min_val=0, max_val=100):

    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix

def selection_sort_matrix(matrix):

  rows = len(matrix)
  cols = len(matrix[0])
  N = rows * cols


  flat_list = [matrix[i][j] for i in range(rows) for j in range(cols)]


  for i in range(N - 1):
    min_val = flat_list[i]
    min_index = i
    for j in range(i + 1, N):
      if flat_list[j] < min_val:
        min_val = flat_list[j]
        min_index = j

    if min_index != i:
      flat_list[i], flat_list[min_index] = flat_list[min_index], flat_list[i]


  sorted_matrix = []
  for i in range(0, N, cols):
    sorted_matrix.append(flat_list[i:i + cols])

  return sorted_matrix


rows = 4
cols = 4
min_value = 2
max_value = 19

my_matrix = generate_matrix(rows, cols, min_value, max_value)

print("Исходная матрица:")
for row in my_matrix:
    print(row)

sorted_matrix = selection_sort_matrix(my_matrix)

print("\nОтсортированная матрица (построчно):")
for row in sorted_matrix:
    print(row)
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Исходная матрица:
# [19, 18, 7, 10]
# [18, 5, 16, 7]
# [4, 16, 19, 12]
# [14, 11, 13, 2]
#
# Отсортированная матрица (построчно):
# [2, 4, 5, 7]
# [7, 10, 11, 12]
# [13, 14, 16, 16]
# [18, 18, 19, 19]
# --- 0 ms ---

# %%
# Сортировка вставкой.
start_time = time.time()

import copy
import random

def generate_matrix(rows, cols, min_val=0, max_val=100):

    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix


def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key


def sort_matrix(matrix, cols):
    cop1 = copy.deepcopy(matrix)
    cop3 = []
    for row in cop1:
        cop3.extend(row)

    insertion_sort(cop3)

    sorte = []
    for i in range(0, len(cop3), cols):
        sorte.append(cop3[i:i + cols])
    return sorte


def print_matrix(matrix, title=""):
    if title:
        print(title)
    for row in matrix:
        print(row)


rows = 3 
cols = 4 
min_val = 0  
max_val = 100

    
mtx = generate_matrix(rows, cols, min_val, max_val)
print_matrix(mtx, "Исходная матрица:")

    
sorted_matrix = sort_matrix(mtx, user_n)

    
print_matrix(sorted_matrix, "Сортировка вставкой (по строкам):")

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Исходная матрица:
# [0, 38, 94, 26]
# [59, 38, 83, 52]
# [89, 53, 54, 92]
# Сортировка вставкой (по строкам):
# [0, 26, 38]
# [38, 52, 53]
# [54, 59, 83]
# [89, 92, 94]
# --- 0 ms ---

# %%
# Сортировка обменом. || Сортировка пузырьком.
start_time = time.time()

import random
import copy


def generate_matrix(rows, cols, min_val=0, max_val=100):
    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix


def bub_sor(A):
    for j in range(len(A) - 1):
        for i in range(len(A) - 1 - j):
            if A[i] > A[i + 1]:
                A[i], A[i + 1] = A[i + 1], A[i]


rows = int(input("Введите количество строк матрицы: "))
cols = int(input("Введите количество столбцов матрицы: "))
user_n = int(input("Введите размер подматрицы для вывода (N): "))


mtx = generate_matrix(rows, cols)
print("Исходная матрица:")
for row in mtx:
    print(row)


cop4 = copy.deepcopy(mtx)  
cop5 = []
for i in cop4:
    for i2 in i:
        cop5.append(i2)
N = len(cop5)
bub_sor(cop5)


sorte = []
for i in range(0, N, user_n):
    sorte.append(cop5[i:i + user_n])


print("\nСортировка пузырьком:")
for row in sorte:
    print(row)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Исходная матрица:
# [98, 75, 88, 54]
# [8, 95, 43, 69]
# [93, 73, 63, 97]
#
# Сортировка пузырьком:
# [8, 43, 54]
# [63, 69, 73]
# [75, 88, 93]
# [95, 97, 98]
# --- 4267 ms ---

# %%
# Сортировка Шелла.
start_time = time.time()
import random

def generate_matrix(rows, cols, min_val=0, max_val=100):
    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix


def shell_sort(arr):

    n = len(arr)
    gap = n // 2

    while gap > 0:
        for i in range(gap, n):
            temp = arr[i]
            j = i
            while j >= gap and arr[j - gap] > temp:
                arr[j] = arr[j - gap]
                j -= gap
            arr[j] = temp
        gap //= 2
    return arr


def print_matrix(matrix):
    for row in matrix:
        print(row)

rows = 3
cols = 3
min_value = 0
max_value = 100

    
random_matrix = generate_matrix(rows, cols, min_value, max_value)

print("Исходная матрица:")
print_matrix(random_matrix)


    
sorted_matrix = []
for row in random_matrix:
    sorted_row = shell_sort(row)
    sorted_matrix.append(sorted_row)

print("\nМатрица с отсортированными строками (сортировка Шелла):")
print_matrix(sorted_matrix)


print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Исходная матрица:
# [66, 89, 60]
# [24, 29, 91]
# [100, 74, 83]
#
# Матрица с отсортированными строками (сортировка Шелла):
# [60, 66, 89]
# [24, 29, 91]
# [74, 83, 100]
# --- 0 ms ---

# %%
# Быстрая сортировка.
start_time = time.time()
import random

def generate_matrix(rows, cols, min_val=0, max_val=100):
    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix

def print_matrix(matrix):
    for row in matrix:
        print(row)

def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]  
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

rows = 5
cols = 4
min_value = 0
max_value = 100

random_matrix = generate_matrix(rows, cols, min_value, max_value)
print("Исходная матрица:")
print_matrix(random_matrix)

flat_list = [element for row in random_matrix for element in row]

sorted_list = quicksort(flat_list)

sorted_matrix = []
for i in range(rows):
    sorted_matrix.append(sorted_list[i*cols:(i+1)*cols])

print("\nОтсортированная матрица:")
print_matrix(sorted_matrix)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# Исходная матрица:
# [87, 46, 1, 97]
# [25, 79, 2, 71]
# [86, 16, 68, 95]
# [18, 25, 43, 86]
# [17, 65, 22, 37]
#
# Отсортированная матрица:
# [1, 2, 16, 17]
# [18, 22, 25, 25]
# [37, 43, 46, 65]
# [68, 71, 79, 86]
# [86, 87, 95, 97]
# --- 0 ms ---

# %%
# Турнирная сортировка
import heapq
import time
import random

start_time = time.time()


def tournament_sort(data):
    size = len(data)
    if size <= 1:
        return data 

    heap = []
    for i in range(0, size, 2):
        if i + 1 < size:
            heap.append(min(data[i], data[i + 1]))
        else:
            heap.append(data[i]) 

    heapq.heapify(heap)

    sorted_list = []
    indices = {}

    for element in heap:
        indices[element] = [i for i, x in enumerate(data) if x == element][
            0] 

    while heap:
        winner = heapq.heappop(heap)
        sorted_list.append(winner)

        winner_index = indices[winner]
        pair_index = winner_index ^ 1 

        if pair_index < size:
            try:
                index_in_heap = heap.index(winner)  
            except ValueError:
                index_in_heap = -1

            if index_in_heap >= 0:
                loser = data[pair_index]

                heapq.heappush(heap, loser)
                indices[loser] = pair_index

    return sorted_list


def generate_matrix(rows, cols, min_val, max_val):
    matrix = []
    for _ in range(rows):
        row = [random.randint(min_val, max_val) for _ in range(cols)]
        matrix.append(row)
    return matrix

rows = 5
cols = 5
min_val = 1
max_val = 100

random_matrix = generate_matrix(rows, cols, min_val, max_val)

print("Original Matrix:")
for row in random_matrix:
    print(row)

flattened_list = [element for row in random_matrix for element in row]

sorted_data = tournament_sort(flattened_list)

print("\nSorted Flattened List:")
print(sorted_data)

print("--- {0} ms ---".format(round((time.time() - start_time) * 1000)))
# Out:
# Original Matrix:
# [10, 56, 92, 30, 70]
# [79, 76, 15, 66, 42]
# [46, 46, 57, 94, 48]
# [11, 54, 42, 16, 47]
# [6, 82, 15, 62, 9]
#
# Sorted Flattened List:
# [6, 9, 10, 11, 15, 15, 16, 30, 42, 42, 46, 57, 66, 70, 76]
# --- 2 ms ---

# %%
# Пирамидальная сортировка
import time
import random
import numpy as np

start_time = time.time()

def heapify(arr, n, i):
  largest = i  
  left = 2 * i + 1 
  right = 2 * i + 2 

  if left < n and arr[i] < arr[left]:
    largest = left

  if right < n and arr[largest] < arr[right]:
    largest = right

  if largest != i:
    arr[i], arr[largest] = arr[largest], arr[i]

    heapify(arr, n, largest)


def heap_sort(arr, matrix_size=None):
  n = len(arr)
  if matrix_size is not None:
      matrix_rows, matrix_cols = matrix_size
      print("Исходная матрица:")
      print(np.array(arr).reshape((matrix_rows, matrix_cols)))
      print("-" * 20)


  for i in range(n // 2 - 1, -1, -1): 
    heapify(arr, n, i)
    if matrix_size is not None:
        print(f"После heapify {i} - формирование Max-кучи:")
        print(np.array(arr).reshape((matrix_rows, matrix_cols)))
        print("-" * 20)

  for i in range(n - 1, 0, -1):
    arr[0], arr[i] = arr[i], arr[0]
    if matrix_size is not None:
        print(f"Меняем arr[0] и arr[{i}]")
        print(np.array(arr).reshape((matrix_rows, matrix_cols)))
        print("-" * 20)

    heapify(arr, i, 0)
    if matrix_size is not None:
        try:
            print(f"После heapify (размер кучи {i}):")
            print(np.array(arr[:i]).reshape((matrix_rows, matrix_cols)))
            print("-" * 20)

        except ValueError:
            print(f"  Невозможно отобразить кучу размера {i} в матрицу {matrix_rows}x{matrix_cols}")
            print(f"  Текущий размер массива arr[:{i}]: {len(arr[:i])}")
            print("-" * 20)
  return arr

start_time = time.time()
matrix_rows = 3
matrix_cols = 4
matrix_size = (matrix_rows, matrix_cols)
arr = [random.randint(1, 99) for _ in range(matrix_rows * matrix_cols)]

print("Размер матрицы:", matrix_size)
sorted_arr = heap_sort(arr, matrix_size)
print("Отсортированная матрица (как одномерный массив):", sorted_arr)

print("--- {0} ms ---".format(round((time.time() - start_time) * 1000)))
# Out:
# Размер матрицы: (3, 4)
# Исходная матрица:
# [[72 90 41 86]
#  [69 42 70 63]
#  [49 95 81 22]]
# --------------------
# После heapify 5 - формирование Max-кучи:
# [[72 90 41 86]
#  [69 42 70 63]
#  [49 95 81 22]]
# --------------------
# После heapify 4 - формирование Max-кучи:
# [[72 90 41 86]
#  [95 42 70 63]
#  [49 69 81 22]]
# --------------------
# После heapify 3 - формирование Max-кучи:
# [[72 90 41 86]
#  [95 42 70 63]
#  [49 69 81 22]]
# --------------------
# После heapify 2 - формирование Max-кучи:
# [[72 90 70 86]
#  [95 42 41 63]
#  [49 69 81 22]]
# --------------------
# После heapify 1 - формирование Max-кучи:
# [[72 95 70 86]
#  [90 42 41 63]
#  [49 69 81 22]]
# --------------------
# После heapify 0 - формирование Max-кучи:
# [[95 90 70 86]
#  [81 42 41 63]
#  [49 69 72 22]]
# --------------------
# Меняем arr[0] и arr[11]
# [[22 90 70 86]
#  [81 42 41 63]
#  [49 69 72 95]]
# --------------------
# После heapify (размер кучи 11):
# ...

# %% [markdown]
# ### Вывод
